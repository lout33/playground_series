# %%
import pyttsx3

# %%
synthesizer = pyttsx3.init()

# %%
synthesizer.say("Hello World") 
synthesizer.runAndWait() 
synthesizer.stop()

# %%
synthesizer.save_to_file("Hello World", 'test.mp3')
synthesizer.runAndWait()

# %%
voices = synthesizer.getProperty('voices')
for voice in voices: 
    print("Voice:") 
    print("ID: %s" %voice.id) 
    print("Name: %s" %voice.name) 
    print("Age: %s" %voice.age) 
    print("Gender: %s" %voice.gender) 
    print("Languages Known: %s" %voice.languages)
# Out:
# Voice:
# ID: com.apple.speech.synthesis.voice.Agnes
# Name: Agnes
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.Albert
# Name: Albert
# Age: 30
# Gender: VoiceGenderNeuter
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.Alex
# Name: Alex
# Age: 35
# Gender: VoiceGenderMale
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.alice
# Name: Alice
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['it_IT']
# Voice:
# ID: com.apple.speech.synthesis.voice.alva
# Name: Alva
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['sv_SE']
# Voice:
# ID: com.apple.speech.synthesis.voice.amelie
# Name: Amelie
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['fr_CA']
# Voice:
# ID: com.apple.speech.synthesis.voice.angelica.premium
# Name: Angelica
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['es_MX']
# Voice:
# ID: com.apple.speech.synthesis.voice.anna
# Name: Anna
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['de_DE']
# Voice:
# ID: com.apple.speech.synthesis.voice.BadNews
# Name: Bad News
# Age: 50
# Gender: VoiceGenderNeuter
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.Bahh
# Name: Bahh
# Age: 2
# Gender: VoiceGenderNeuter
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.Bells
# Name: Bells
# Age: 100
# Gender: VoiceGenderNeuter
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.Boing
# Name: Boing
# Age: 1
# Gender: VoiceGenderNeuter
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.Bruce
# Name: Bruce
# Age: 35
# Gender: VoiceGenderMale
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.Bubbles
# Name: Bubbles
# Age: 0
# Gender: VoiceGenderNeuter
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.carlos.premium
# Name: Carlos
# Age: 35
# Gender: VoiceGenderMale
# Languages Known: ['es_CO']
# Voice:
# ID: com.apple.speech.synthesis.voice.carmit
# Name: Carmit
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['he_IL']
# Voice:
# ID: com.apple.speech.synthesis.voice.Cellos
# Name: Cellos
# Age: 50
# Gender: VoiceGenderNeuter
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.damayanti
# Name: Damayanti
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['id_ID']
# Voice:
# ID: com.apple.speech.synthesis.voice.daniel
# Name: Daniel
# Age: 35
# Gender: VoiceGenderMale
# Languages Known: ['en_GB']
# Voice:
# ID: com.apple.speech.synthesis.voice.Deranged
# Name: Deranged
# Age: 30
# Gender: VoiceGenderNeuter
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.diego.premium
# Name: Diego
# Age: 35
# Gender: VoiceGenderMale
# Languages Known: ['es_AR']
# Voice:
# ID: com.apple.speech.synthesis.voice.ellen
# Name: Ellen
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['nl_BE']
# Voice:
# ID: com.apple.speech.synthesis.voice.fiona
# Name: Fiona
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['en-scotland']
# Voice:
# ID: com.apple.speech.synthesis.voice.Fred
# Name: Fred
# Age: 30
# Gender: VoiceGenderMale
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.GoodNews
# Name: Good News
# Age: 8
# Gender: VoiceGenderNeuter
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.Hysterical
# Name: Hysterical
# Age: 30
# Gender: VoiceGenderNeuter
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.ioana
# Name: Ioana
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['ro_RO']
# Voice:
# ID: com.apple.speech.synthesis.voice.joana
# Name: Joana
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['pt_PT']
# Voice:
# ID: com.apple.speech.synthesis.voice.jorge.premium
# Name: Jorge
# Age: 35
# Gender: VoiceGenderMale
# Languages Known: ['es_ES']
# Voice:
# ID: com.apple.speech.synthesis.voice.juan.premium
# Name: Juan
# Age: 35
# Gender: VoiceGenderMale
# Languages Known: ['es_MX']
# Voice:
# ID: com.apple.speech.synthesis.voice.Junior
# Name: Junior
# Age: 8
# Gender: VoiceGenderMale
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.kanya
# Name: Kanya
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['th_TH']
# Voice:
# ID: com.apple.speech.synthesis.voice.karen
# Name: Karen
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['en_AU']
# Voice:
# ID: com.apple.speech.synthesis.voice.Kathy
# Name: Kathy
# Age: 30
# Gender: VoiceGenderFemale
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.kyoko
# Name: Kyoko
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['ja_JP']
# Voice:
# ID: com.apple.speech.synthesis.voice.laura
# Name: Laura
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['sk_SK']
# Voice:
# ID: com.apple.speech.synthesis.voice.lee
# Name: Lee
# Age: 35
# Gender: VoiceGenderMale
# Languages Known: ['en_AU']
# Voice:
# ID: com.apple.speech.synthesis.voice.lekha
# Name: Lekha
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['hi_IN']
# Voice:
# ID: com.apple.speech.synthesis.voice.luca
# Name: Luca
# Age: 35
# Gender: VoiceGenderMale
# Languages Known: ['it_IT']
# Voice:
# ID: com.apple.speech.synthesis.voice.luciana
# Name: Luciana
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['pt_BR']
# Voice:
# ID: com.apple.speech.synthesis.voice.maged
# Name: Maged
# Age: 35
# Gender: VoiceGenderMale
# Languages Known: ['ar_SA']
# Voice:
# ID: com.apple.speech.synthesis.voice.mariska
# Name: Mariska
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['hu_HU']
# Voice:
# ID: com.apple.speech.synthesis.voice.mei-jia
# Name: Mei-Jia
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['zh_TW']
# Voice:
# ID: com.apple.speech.synthesis.voice.melina
# Name: Melina
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['el_GR']
# Voice:
# ID: com.apple.speech.synthesis.voice.milena
# Name: Milena
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['ru_RU']
# Voice:
# ID: com.apple.speech.synthesis.voice.moira
# Name: Moira
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['en_IE']
# Voice:
# ID: com.apple.speech.synthesis.voice.monica.premium
# Name: Monica
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['es_ES']
# Voice:
# ID: com.apple.speech.synthesis.voice.nora
# Name: Nora
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['nb_NO']
# Voice:
# ID: com.apple.speech.synthesis.voice.paulina.premium
# Name: Paulina
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['es_MX']
# Voice:
# ID: com.apple.speech.synthesis.voice.Organ
# Name: Pipe Organ
# Age: 500
# Gender: VoiceGenderNeuter
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.Princess
# Name: Princess
# Age: 8
# Gender: VoiceGenderFemale
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.Ralph
# Name: Ralph
# Age: 50
# Gender: VoiceGenderMale
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.rishi
# Name: Rishi
# Age: 35
# Gender: VoiceGenderMale
# Languages Known: ['en_IN']
# Voice:
# ID: com.apple.speech.synthesis.voice.samantha
# Name: Samantha
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.sara
# Name: Sara
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['da_DK']
# Voice:
# ID: com.apple.speech.synthesis.voice.satu
# Name: Satu
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['fi_FI']
# Voice:
# ID: com.apple.speech.synthesis.voice.sin-ji
# Name: Sin-ji
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['zh_HK']
# Voice:
# ID: com.apple.speech.synthesis.voice.soledad.premium
# Name: Soledad
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['es_CO']
# Voice:
# ID: com.apple.speech.synthesis.voice.tessa
# Name: Tessa
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['en_ZA']
# Voice:
# ID: com.apple.speech.synthesis.voice.thomas
# Name: Thomas
# Age: 35
# Gender: VoiceGenderMale
# Languages Known: ['fr_FR']
# Voice:
# ID: com.apple.speech.synthesis.voice.ting-ting
# Name: Ting-Ting
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['zh_CN']
# Voice:
# ID: com.apple.speech.synthesis.voice.tom.premium
# Name: Tom
# Age: 35
# Gender: VoiceGenderMale
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.Trinoids
# Name: Trinoids
# Age: 2001
# Gender: VoiceGenderNeuter
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.veena
# Name: Veena
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['en_IN']
# Voice:
# ID: com.apple.speech.synthesis.voice.Vicki
# Name: Vicki
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.Victoria
# Name: Victoria
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.Whisper
# Name: Whisper
# Age: 30
# Gender: VoiceGenderNeuter
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.Zarvox
# Name: Zarvox
# Age: 1
# Gender: VoiceGenderNeuter
# Languages Known: ['en_US']
# Voice:
# ID: com.apple.speech.synthesis.voice.zuzana
# Name: Zuzana
# Age: 35
# Gender: VoiceGenderFemale
# Languages Known: ['cs_CZ']
